# %%
import greetings

# %%
print(greetings.__name__)
# Out:
# greetings

# %%
# %run greetings.py
# Out:
# Top-level code ran
# This file is being run directly: __name__ is __main__
# Hello, student!
