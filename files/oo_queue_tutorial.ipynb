# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

# %%
class Queue:
    def __init__(self):
        self.front = None
        self.rear = None
        self._size = 0

    def is_empty(self):
        # TODO: Return True if the queue is empty.
        pass

    def enqueue(self, value):
        new_node = Node(value)

        if self.is_empty():
            # TODO: Set both front and rear to new_node.
            pass
        else:
            # TODO: Link the old rear to new_node.
            pass

            # TODO: Move rear to new_node.
            pass

        # TODO: Increase the size.
        pass

    def dequeue(self):
        if self.is_empty():
            raise IndexError("Cannot dequeue from an empty queue")

        # TODO: Save the front node in a variable.
        pass

        # TODO: Move front to the next node.
        pass

        # TODO: Decrease the size.
        pass

        if self._size == 0:
            # TODO: Set rear to None.
            pass

        # TODO: Return the removed node's value.
        pass

    def peek(self):
        if self.is_empty():
            raise IndexError("Cannot peek at an empty queue")

        # TODO: Return the value at the front.
        pass

    def __len__(self):
        # TODO: Return the queue size.
        pass

    def __repr__(self):
        values = []
        current = self.front

        while current is not None:
            values.append(repr(current.value))
            current = current.next

        return "Queue([" + ", ".join(values) + "])"

# %%
queue = Queue()

queue.enqueue("A")
queue.enqueue("B")
queue.enqueue("C")

print(queue)
print("Front:", queue.peek())
print("Removed:", queue.dequeue())
print(queue)

# %%
queue = Queue()

assert queue.is_empty()
assert len(queue) == 0

queue.enqueue(10)

assert not queue.is_empty()
assert len(queue) == 1
assert queue.peek() == 10
assert queue.front.value == 10
assert queue.rear.value == 10

queue.enqueue(20)
queue.enqueue(30)

assert len(queue) == 3
assert queue.peek() == 10
assert queue.rear.value == 30

assert queue.dequeue() == 10
assert queue.dequeue() == 20
assert queue.dequeue() == 30

assert queue.is_empty()
assert queue.front is None
assert queue.rear is None

print("All tests passed.")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[3], line 3
#       1 queue = Queue()
# ----> 3 assert queue.is_empty()
#       4 assert len(queue) == 0
#       6 queue.enqueue(10)
#
# AssertionError:

# %%
queue = Queue()

queue.enqueue("A")
queue.enqueue("B")
queue.enqueue("C")

assert queue.front.value == "A"
assert queue.front.next.value == "B"
assert queue.front.next.next.value == "C"
assert queue.front.next.next.next is None

assert queue.rear.value == "C"
assert queue.rear.next is None

print("Node-link tests passed.")

# %% [markdown]
# ## Important edge case
#
# When the last item is removed, both references must become `None`:

# %%
queue = Queue()

queue.enqueue("only item")

assert queue.front is queue.rear

assert queue.dequeue() == "only item"

assert queue.front is None
assert queue.rear is None
assert queue.is_empty()

print("Single-node test passed.")

# %%
def process_tasks(task_queue):
    """
    Remove and return all tasks in the order they should be processed.
    """
    completed = []

    # TODO: Continue while the queue is not empty

    # TODO: Remove a task and add it to completed

    return completed

# %%
task_queue = Queue()

task_queue.enqueue("Task 1")
task_queue.enqueue("Task 2")
task_queue.enqueue("Task 3")

result = process_tasks(task_queue)

assert result == ["Task 1", "Task 2", "Task 3"]
assert task_queue.is_empty()

print("Final task-processing test passed.")
