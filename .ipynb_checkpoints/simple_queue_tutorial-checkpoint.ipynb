# %%
class Queue:
    """A simple FIFO queue implemented with a Python list."""

    def __init__(self):
        """Create an empty queue."""
        self._items = []

    def enqueue(self, item):
        """Add an item to the back of the queue."""
        # TODO: Add item to the back of the queue
        pass

    def dequeue(self):
        """Remove and return the item at the front of the queue."""
        # TODO: Raise IndexError if the queue is empty

        # TODO: Remove and return the front item
        pass

    def peek(self):
        """Return the front item without removing it."""
        # TODO: Raise IndexError if the queue is empty

        # TODO: Return the front item without removing it
        pass

    def is_empty(self):
        """Return True if the queue contains no items."""
        # TODO: Return True when the queue is empty
        pass

    def __len__(self):
        """Return the number of items in the queue."""
        # TODO: Return the number of items
        pass

    def __repr__(self):
        """Return a useful representation of the queue."""
        return f"Queue({self._items!r})"

# %%
queue = Queue()

assert queue.is_empty(), "A new queue should be empty"
assert len(queue) == 0, "A new queue should have length 0"

queue.enqueue("A")

assert not queue.is_empty(), "The queue should not be empty"
assert len(queue) == 1, "The queue should have length 1"
assert queue.peek() == "A", "peek should return the first item"
assert len(queue) == 1, "peek should not remove the item"

queue.enqueue("B")
queue.enqueue("C")

assert len(queue) == 3
assert queue.peek() == "A"

assert queue.dequeue() == "A", "The first item should be removed first"
assert queue.dequeue() == "B", "The second item should be removed second"
assert queue.dequeue() == "C", "The third item should be removed third"

assert queue.is_empty()
assert len(queue) == 0

print("Basic tests passed.")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[7], line 3
#       1 queue = Queue()
# ----> 3 assert queue.is_empty(), "A new queue should be empty"
#       4 assert len(queue) == 0, "A new queue should have length 0"
#       6 queue.enqueue("A")
#
# AssertionError: A new queue should be empty

# %%
empty_queue = Queue()

try:
    empty_queue.dequeue()
    assert False, "dequeue should raise IndexError on an empty queue"
except IndexError:
    pass

try:
    empty_queue.peek()
    assert False, "peek should raise IndexError on an empty queue"
except IndexError:
    pass

print("Error-handling tests passed.")

# %%
def process_tasks(tasks):
    """
    Remove and return all tasks in the order they should be processed.
    """
    completed = []

    # TODO: Continue while the queue is not empty

        # TODO: Remove a task and add it to completed

    return completed

# %%
task_queue = Queue()

task_queue.enqueue("Task 1")
task_queue.enqueue("Task 2")
task_queue.enqueue("Task 3")

result = process_tasks(task_queue)

assert result == ["Task 1", "Task 2", "Task 3"]
assert task_queue.is_empty()

print("Final task-processing test passed.")
